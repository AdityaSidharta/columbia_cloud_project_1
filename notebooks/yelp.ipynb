# %%
import requests
import pandas as pd

# %%
API_KEY = 'https://www.yelp.com/developers/v3/manage_app?app_created=True'

# %%
TERMS = [
    'chinese food',
    'american food',
    'japanese food',
    'french food'
]

LOCATIONS = [
    'manhattan',
    'queens',
    'brooklyn'
]

# %%
my_headers = {'Authorization' : 'Bearer {}'.format(API_KEY)}

# %%
OFFSETS = range(0, 1000, 50)

# %%
URL = "https://api.yelp.com/v3/businesses/search"
LIMIT = 50

# %%
FINAL_OUTPUT = []

# %%
def is_valid(raw):
    if 'id' not in raw:
        return False
    if 'name' not in raw:
        return False
    if 'location' not in raw:
        return False
    if 'coordinates' not in raw:
        return False
    if 'review_count' not in raw:
        return False
    if 'rating' not in raw:
        return False
    return True
        
def get_info(raw, query, location):
    output = {
        'id': raw['id'],
        'name': raw['name'],
        'address': ', '.join(raw['location']['display_address']),
        'coordinates': (raw['coordinates']['latitude'], raw['coordinates']['longitude']),
        'review_count': raw['review_count'],
        'rating': raw['rating'],
        'zip_code': raw['location']['zip_code'],
        'query': query,
        'location': location
    }
    return output

# %%
for term in TERMS:
    for location in LOCATIONS:
        for offset in OFFSETS:
            print("term : {}, location : {}, offset : {}".format(term, location, offset))
            r = requests.get(URL, 
                 params={"term": term, "location": location, "limit": LIMIT, "offset": offset}, 
                 headers=my_headers)
            for business in r.json()['businesses']:
                if is_valid(business):
                    output = get_info(business, term, location)
                    FINAL_OUTPUT.append(output)
# Out:
# term : chinese food, location : manhattan, offset : 0
# term : chinese food, location : manhattan, offset : 50
# term : chinese food, location : manhattan, offset : 100
# term : chinese food, location : manhattan, offset : 150
# term : chinese food, location : manhattan, offset : 200
# term : chinese food, location : manhattan, offset : 250
# term : chinese food, location : manhattan, offset : 300
# term : chinese food, location : manhattan, offset : 350
# term : chinese food, location : manhattan, offset : 400
# term : chinese food, location : manhattan, offset : 450
# term : chinese food, location : manhattan, offset : 500
# term : chinese food, location : manhattan, offset : 550
# term : chinese food, location : manhattan, offset : 600
# term : chinese food, location : manhattan, offset : 650
# term : chinese food, location : manhattan, offset : 700
# term : chinese food, location : manhattan, offset : 750
# term : chinese food, location : manhattan, offset : 800
# term : chinese food, location : manhattan, offset : 850
# term : chinese food, location : manhattan, offset : 900
# term : chinese food, location : manhattan, offset : 950
# term : chinese food, location : queens, offset : 0
# term : chinese food, location : queens, offset : 50
# term : chinese food, location : queens, offset : 100
# term : chinese food, location : queens, offset : 150
# term : chinese food, location : queens, offset : 200
# term : chinese food, location : queens, offset : 250
# term : chinese food, location : queens, offset : 300
# term : chinese food, location : queens, offset : 350
# term : chinese food, location : queens, offset : 400
# term : chinese food, location : queens, offset : 450
# term : chinese food, location : queens, offset : 500
# term : chinese food, location : queens, offset : 550
# term : chinese food, location : queens, offset : 600
# term : chinese food, location : queens, offset : 650
# term : chinese food, location : queens, offset : 700
# term : chinese food, location : queens, offset : 750
# term : chinese food, location : queens, offset : 800
# term : chinese food, location : queens, offset : 850
# term : chinese food, location : queens, offset : 900
# term : chinese food, location : queens, offset : 950
# term : chinese food, location : brooklyn, offset : 0
# term : chinese food, location : brooklyn, offset : 50
# term : chinese food, location : brooklyn, offset : 100
# term : chinese food, location : brooklyn, offset : 150
# term : chinese food, location : brooklyn, offset : 200
# term : chinese food, location : brooklyn, offset : 250
# term : chinese food, location : brooklyn, offset : 300
# term : chinese food, location : brooklyn, offset : 350
# term : chinese food, location : brooklyn, offset : 400
# term : chinese food, location : brooklyn, offset : 450
# term : chinese food, location : brooklyn, offset : 500
# term : chinese food, location : brooklyn, offset : 550
# term : chinese food, location : brooklyn, offset : 600
# term : chinese food, location : brooklyn, offset : 650
# term : chinese food, location : brooklyn, offset : 700
# term : chinese food, location : brooklyn, offset : 750
# term : chinese food, location : brooklyn, offset : 800
# term : chinese food, location : brooklyn, offset : 850
# term : chinese food, location : brooklyn, offset : 900
# term : chinese food, location : brooklyn, offset : 950
# term : american food, location : manhattan, offset : 0
# term : american food, location : manhattan, offset : 50
# term : american food, location : manhattan, offset : 100
# term : american food, location : manhattan, offset : 150
# term : american food, location : manhattan, offset : 200
# term : american food, location : manhattan, offset : 250
# term : american food, location : manhattan, offset : 300
# term : american food, location : manhattan, offset : 350
# term : american food, location : manhattan, offset : 400
# term : american food, location : manhattan, offset : 450
# term : american food, location : manhattan, offset : 500
# term : american food, location : manhattan, offset : 550
# term : american food, location : manhattan, offset : 600
# term : american food, location : manhattan, offset : 650
# term : american food, location : manhattan, offset : 700
# term : american food, location : manhattan, offset : 750
# term : american food, location : manhattan, offset : 800
# term : american food, location : manhattan, offset : 850
# term : american food, location : manhattan, offset : 900
# term : american food, location : manhattan, offset : 950
# term : american food, location : queens, offset : 0
# term : american food, location : queens, offset : 50
# term : american food, location : queens, offset : 100
# term : american food, location : queens, offset : 150
# term : american food, location : queens, offset : 200
# term : american food, location : queens, offset : 250
# term : american food, location : queens, offset : 300
# term : american food, location : queens, offset : 350
# term : american food, location : queens, offset : 400
# term : american food, location : queens, offset : 450
# term : american food, location : queens, offset : 500
# term : american food, location : queens, offset : 550
# term : american food, location : queens, offset : 600
# term : american food, location : queens, offset : 650
# term : american food, location : queens, offset : 700
# term : american food, location : queens, offset : 750
# term : american food, location : queens, offset : 800
# term : american food, location : queens, offset : 850
# term : american food, location : queens, offset : 900
# term : american food, location : queens, offset : 950
# term : american food, location : brooklyn, offset : 0
# term : american food, location : brooklyn, offset : 50
# term : american food, location : brooklyn, offset : 100
# term : american food, location : brooklyn, offset : 150
# term : american food, location : brooklyn, offset : 200
# term : american food, location : brooklyn, offset : 250
# term : american food, location : brooklyn, offset : 300
# term : american food, location : brooklyn, offset : 350
# term : american food, location : brooklyn, offset : 400
# term : american food, location : brooklyn, offset : 450
# term : american food, location : brooklyn, offset : 500
# term : american food, location : brooklyn, offset : 550
# term : american food, location : brooklyn, offset : 600
# term : american food, location : brooklyn, offset : 650
# term : american food, location : brooklyn, offset : 700
# term : american food, location : brooklyn, offset : 750
# term : american food, location : brooklyn, offset : 800
# term : american food, location : brooklyn, offset : 850
# term : american food, location : brooklyn, offset : 900
# term : american food, location : brooklyn, offset : 950
# term : japanese food, location : manhattan, offset : 0
# term : japanese food, location : manhattan, offset : 50
# term : japanese food, location : manhattan, offset : 100
# term : japanese food, location : manhattan, offset : 150
# term : japanese food, location : manhattan, offset : 200
# term : japanese food, location : manhattan, offset : 250
# term : japanese food, location : manhattan, offset : 300
# term : japanese food, location : manhattan, offset : 350
# term : japanese food, location : manhattan, offset : 400
# term : japanese food, location : manhattan, offset : 450
# term : japanese food, location : manhattan, offset : 500
# term : japanese food, location : manhattan, offset : 550
# term : japanese food, location : manhattan, offset : 600
# term : japanese food, location : manhattan, offset : 650
# term : japanese food, location : manhattan, offset : 700
# term : japanese food, location : manhattan, offset : 750
# term : japanese food, location : manhattan, offset : 800
# term : japanese food, location : manhattan, offset : 850
# term : japanese food, location : manhattan, offset : 900
# term : japanese food, location : manhattan, offset : 950
# term : japanese food, location : queens, offset : 0
# term : japanese food, location : queens, offset : 50
# term : japanese food, location : queens, offset : 100
# term : japanese food, location : queens, offset : 150
# term : japanese food, location : queens, offset : 200
# term : japanese food, location : queens, offset : 250
# term : japanese food, location : queens, offset : 300
# term : japanese food, location : queens, offset : 350
# term : japanese food, location : queens, offset : 400
# term : japanese food, location : queens, offset : 450
# term : japanese food, location : queens, offset : 500
# term : japanese food, location : queens, offset : 550
# term : japanese food, location : queens, offset : 600
# term : japanese food, location : queens, offset : 650
# term : japanese food, location : queens, offset : 700
# term : japanese food, location : queens, offset : 750
# term : japanese food, location : queens, offset : 800
# term : japanese food, location : queens, offset : 850
# term : japanese food, location : queens, offset : 900
# term : japanese food, location : queens, offset : 950
# term : japanese food, location : brooklyn, offset : 0
# term : japanese food, location : brooklyn, offset : 50
# term : japanese food, location : brooklyn, offset : 100
# term : japanese food, location : brooklyn, offset : 150
# term : japanese food, location : brooklyn, offset : 200
# term : japanese food, location : brooklyn, offset : 250
# term : japanese food, location : brooklyn, offset : 300
# term : japanese food, location : brooklyn, offset : 350
# term : japanese food, location : brooklyn, offset : 400
# term : japanese food, location : brooklyn, offset : 450
# term : japanese food, location : brooklyn, offset : 500
# term : japanese food, location : brooklyn, offset : 550
# term : japanese food, location : brooklyn, offset : 600
# term : japanese food, location : brooklyn, offset : 650
# term : japanese food, location : brooklyn, offset : 700
# term : japanese food, location : brooklyn, offset : 750
# term : japanese food, location : brooklyn, offset : 800
# term : japanese food, location : brooklyn, offset : 850
# term : japanese food, location : brooklyn, offset : 900
# term : japanese food, location : brooklyn, offset : 950
# term : french food, location : manhattan, offset : 0
# term : french food, location : manhattan, offset : 50
# term : french food, location : manhattan, offset : 100
# term : french food, location : manhattan, offset : 150
# term : french food, location : manhattan, offset : 200
# term : french food, location : manhattan, offset : 250
# term : french food, location : manhattan, offset : 300
# term : french food, location : manhattan, offset : 350
# term : french food, location : manhattan, offset : 400
# term : french food, location : manhattan, offset : 450
# term : french food, location : manhattan, offset : 500
# term : french food, location : manhattan, offset : 550
# term : french food, location : manhattan, offset : 600
# term : french food, location : manhattan, offset : 650
# term : french food, location : manhattan, offset : 700
# term : french food, location : manhattan, offset : 750
# term : french food, location : manhattan, offset : 800
# term : french food, location : manhattan, offset : 850
# term : french food, location : manhattan, offset : 900
# term : french food, location : manhattan, offset : 950
# term : french food, location : queens, offset : 0
# term : french food, location : queens, offset : 50
# term : french food, location : queens, offset : 100
# term : french food, location : queens, offset : 150
# term : french food, location : queens, offset : 200
# term : french food, location : queens, offset : 250
# term : french food, location : queens, offset : 300
# term : french food, location : queens, offset : 350
# term : french food, location : queens, offset : 400
# term : french food, location : queens, offset : 450
# term : french food, location : queens, offset : 500
# term : french food, location : queens, offset : 550
# term : french food, location : queens, offset : 600
# term : french food, location : queens, offset : 650
# term : french food, location : queens, offset : 700
# term : french food, location : queens, offset : 750
# term : french food, location : queens, offset : 800
# term : french food, location : queens, offset : 850
# term : french food, location : queens, offset : 900
# term : french food, location : queens, offset : 950
# term : french food, location : brooklyn, offset : 0
# term : french food, location : brooklyn, offset : 50
# term : french food, location : brooklyn, offset : 100
# term : french food, location : brooklyn, offset : 150
# term : french food, location : brooklyn, offset : 200
# term : french food, location : brooklyn, offset : 250
# term : french food, location : brooklyn, offset : 300
# term : french food, location : brooklyn, offset : 350
# term : french food, location : brooklyn, offset : 400
# term : french food, location : brooklyn, offset : 450
# term : french food, location : brooklyn, offset : 500
# term : french food, location : brooklyn, offset : 550
# term : french food, location : brooklyn, offset : 600
# term : french food, location : brooklyn, offset : 650
# term : french food, location : brooklyn, offset : 700
# term : french food, location : brooklyn, offset : 750
# term : french food, location : brooklyn, offset : 800
# term : french food, location : brooklyn, offset : 850
# term : french food, location : brooklyn, offset : 900
# term : french food, location : brooklyn, offset : 950

# %%
df = pd.DataFrame(FINAL_OUTPUT)

# %%
filter_df = df.drop_duplicates('id')

# %%
filter_df.to_csv("")
# Out:
#                            id                           name  \
# 0      XsXLVWr1UZWVhKThNvNiaA                Blue Willow 夜来湘
# 1      bVkjBJlAIwKAj9Aw1KVWjA                 Dim Sum Palace
# 2      EmJ7rfmv2y6lQZxgA8U__g      Red Peony Chinese Cuisine
# 3      UK1oGbr8GU2rufpnJR4-HQ   Joe's Home of Soup Dumplings
# 4      ZWP7yq9C2bhCcLkMR9BmVw                   Mala Project
# ...                       ...                            ...
# 11476  G_FgwVRC4TEfy-8rQCLRQQ  16 Prospect Wine Bar & Bistro
# 11527  Xmb3bFo-Zsb0Liqbu8j9BA                     Buona Sera
# 11529  6-2dLyBlSsOVY0UpfqE9KA                    Don Pepe II
# 11598  66vrcrSXE1KOTusJV4-T3Q               Rosie's Wine Bar
# 11608  qB534YjoC_fx9S1vi3U7bg         Original Pancake House
#
#                                                  address  \
# 0                       40 W 56th St, New York, NY 10019
# 1                      334 W 46th St, New York, NY 10036
# 2                       24 W 56th St, New York, NY 10019
# 3      7 E 48th St, between Fifth and Madison avenues...
# 4                   245 East 53rd St, New York, NY 10022
# ...                                                  ...
# 11476                16 Prospect St, Westfield, NJ 07090
# 11527                   50 Maple Ave, Red Bank, NJ 07701
# 11529            21 Bloomfield Ave, Pine Brook, NJ 07058
# 11598                   514 North Ave, Garwood, NJ 07027
# 11608        817 Bloomfield Ave, West Caldwell, NJ 07006
#
#                                     coordinates  review_count  rating  \
# 0                        (40.76292, -73.976546)           602     4.5
# 1                       (40.76015, -73.9893699)          1548     4.0
# 2                         (40.76278, -73.97589)           513     4.5
# 3                         (40.75723, -73.97702)           304     4.5
# 4       (40.75712551924447, -73.96767713374987)            38     4.5
# ...                                         ...           ...     ...
# 11476                     (40.65048, -74.34858)           166     3.5
# 11527  (40.349046124753876, -74.06950806596338)           419     3.5
# 11529                    (40.859296, -74.34215)           173     3.5
# 11598                 (40.6527785, -74.3298698)           170     3.5
# 11608                  (40.8511396, -74.296983)           421     4.0
#
#       zip_code         query   location
# 0        10019  chinese food  manhattan
# 1        10036  chinese food  manhattan
# 2        10019  chinese food  manhattan
# 3        10017  chinese food  manhattan
# 4        10022  chinese food  manhattan
# ...        ...           ...        ...
# 11476    07090   french food   brooklyn
# 11527    07701   french food   brooklyn
# 11529    07058   french food   brooklyn
# 11598    07027   french food   brooklyn
# 11608    07006   french food   brooklyn
#
# [6034 rows x 9 columns]
